# %%
pip install google-generativeai
# Out:
# Collecting google-generativeai
#   Downloading google_generativeai-0.8.5-py3-none-any.whl.metadata (3.9 kB)
# Collecting google-ai-generativelanguage==0.6.15 (from google-generativeai)
#   Downloading google_ai_generativelanguage-0.6.15-py3-none-any.whl.metadata (5.7 kB)
# Collecting google-api-core (from google-generativeai)
#   Downloading google_api_core-2.24.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting google-api-python-client (from google-generativeai)
#   Downloading google_api_python_client-2.168.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting google-auth>=2.15.0 (from google-generativeai)
#   Downloading google_auth-2.39.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: protobuf in c:\users\mohan\appdata\local\programs\python\python310\lib\site-packages (from google-generativeai) (5.28.3)
# Collecting pydantic (from google-generativeai)
#   Downloading pydantic-2.11.3-py3-none-any.whl.metadata (65 kB)
# Collecting tqdm (from google-generativeai)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions in c:\users\mohan\appdata\roaming\python\python310\site-packages (from google-generativeai) (4.12.2)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-ai-generativelanguage==0.6.15->google-generativeai)
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core->google-generativeai)
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\users\mohan\appdata\local\programs\python\python310\lib\site-packages (from google-api-core->google-generativeai) (2.32.3)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=2.15.0->google-generativeai)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=2.15.0->google-generativeai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=2.15.0->google-generativeai)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client->google-generativeai)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client->google-generativeai)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client->google-generativeai)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting annotated-types>=0.6.0 (from pydantic->google-generativeai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.1 (from pydantic->google-generativeai)
#   Downloading pydantic_core-2.33.1-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic->google-generativeai)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: colorama in c:\users\mohan\appdata\roaming\python\python310\site-packages (from tqdm->google-generativeai) (0.4.6)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\mohan\appdata\local\programs\python\python310\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.67.1)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai)
#   Downloading grpcio_status-1.71.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\mohan\appdata\local\programs\python\python310\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.0)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mohan\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mohan\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mohan\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mohan\appdata\local\programs\python\python310\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2024.8.30)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai)
#   Downloading grpcio-1.71.0-cp310-cp310-win_amd64.whl.metadata (4.0 kB)
# Downloading google_generativeai-0.8.5-py3-none-any.whl (155 kB)
# Downloading google_ai_generativelanguage-0.6.15-py3-none-any.whl (1.3 MB)
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.3 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.3 MB 1.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.3 MB 1.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.3 MB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.3 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 1.1 MB/s eta 0:00:00
# Downloading google_api_core-2.24.2-py3-none-any.whl (160 kB)
# Downloading google_auth-2.39.0-py2.py3-none-any.whl (212 kB)
# Downloading google_api_python_client-2.168.0-py3-none-any.whl (13.3 MB)
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.3 MB 1.5 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/13.3 MB 1.5 MB/s eta 0:00:09
#    -- ------------------------------------- 0.8/13.3 MB 958.5 kB/s eta 0:00:14
#    --- ------------------------------------ 1.0/13.3 MB 931.8 kB/s eta 0:00:14
#    --- ------------------------------------ 1.3/13.3 MB 1.0 MB/s eta 0:00:12
#    ---- ----------------------------------- 1.6/13.3 MB 1.1 MB/s eta 0:00:12
#    ----- ---------------------------------- 1.8/13.3 MB 1.1 MB/s eta 0:00:11
#    ------- -------------------------------- 2.4/13.3 MB 1.2 MB/s eta 0:00:10
#    ------- -------------------------------- 2.6/13.3 MB 1.2 MB/s eta 0:00:09
#    -------- ------------------------------- 2.9/13.3 MB 1.2 MB/s eta 0:00:09
#    --------- ------------------------------ 3.1/13.3 MB 1.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 3.4/13.3 MB 1.3 MB/s eta 0:00:08
#    ----------- ---------------------------- 3.9/13.3 MB 1.3 MB/s eta 0:00:08
#    ------------ --------------------------- 4.2/13.3 MB 1.3 MB/s eta 0:00:07
#    ------------- -------------------------- 4.5/13.3 MB 1.3 MB/s eta 0:00:07
#    -------------- ------------------------- 5.0/13.3 MB 1.4 MB/s eta 0:00:07
#    --------------- ------------------------ 5.2/13.3 MB 1.4 MB/s eta 0:00:06
#    ----------------- ---------------------- 5.8/13.3 MB 1.4 MB/s eta 0:00:06
#    ------------------ --------------------- 6.0/13.3 MB 1.5 MB/s eta 0:00:05
#    ------------------- -------------------- 6.6/13.3 MB 1.5 MB/s eta 0:00:05
#    --------------------- ------------------ 7.1/13.3 MB 1.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 7.3/13.3 MB 1.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 7.9/13.3 MB 1.6 MB/s eta 0:00:04
#    ------------------------- -------------- 8.4/13.3 MB 1.6 MB/s eta 0:00:04
#    -------------------------- ------------- 8.7/13.3 MB 1.6 MB/s eta 0:00:03
#    --------------------------- ------------ 9.2/13.3 MB 1.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 9.7/13.3 MB 1.6 MB/s eta 0:00:03
#    ----------------------------- ---------- 10.0/13.3 MB 1.6 MB/s eta 0:00:03
#    ------------------------------ --------- 10.2/13.3 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 10.7/13.3 MB 1.7 MB/s eta 0:00:02
#    --------------------------------- ------ 11.3/13.3 MB 1.7 MB/s eta 0:00:02
#    ----------------------------------- ---- 11.8/13.3 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 12.1/13.3 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 12.3/13.3 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 12.8/13.3 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.3 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 1.7 MB/s eta 0:00:00
# Downloading pydantic-2.11.3-py3-none-any.whl (443 kB)
# Downloading pydantic_core-2.33.1-cp310-cp310-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 2.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/2.0 MB 1.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.3/2.0 MB 1.6 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 1.5 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading grpcio_status-1.71.0-py3-none-any.whl (14 kB)
# Downloading grpcio-1.71.0-cp310-cp310-win_amd64.whl (4.3 MB)
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.3 MB 1.5 MB/s eta 0:00:03
#    ------- -------------------------------- 0.8/4.3 MB 1.6 MB/s eta 0:00:03
#    ------------ --------------------------- 1.3/4.3 MB 1.7 MB/s eta 0:00:02
#    -------------- ------------------------- 1.6/4.3 MB 1.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 1.8/4.3 MB 1.6 MB/s eta 0:00:02
#    ------------------- -------------------- 2.1/4.3 MB 1.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.4/4.3 MB 1.5 MB/s eta 0:00:02
#    -------------------------- ------------- 2.9/4.3 MB 1.5 MB/s eta 0:00:01
#    -------------------------- ------------- 2.9/4.3 MB 1.5 MB/s eta 0:00:01
#    ------------------------------- -------- 3.4/4.3 MB 1.5 MB/s eta 0:00:01
#    ------------------------------- -------- 3.4/4.3 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.7/4.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  4.2/4.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 4.3/4.3 MB 1.4 MB/s eta 0:00:00
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: uritemplate, typing-inspection, tqdm, pydantic-core, pyasn1, proto-plus, httplib2, grpcio, googleapis-common-protos, cachetools, annotated-types, rsa, pydantic, pyasn1-modules, grpcio-status, google-auth, google-auth-httplib2, google-api-core, google-api-python-client, google-ai-generativelanguage, google-generativeai
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.67.1
#     Uninstalling grpcio-1.67.1:
#       Successfully uninstalled grpcio-1.67.1
# Successfully installed annotated-types-0.7.0 cachetools-5.5.2 google-ai-generativelanguage-0.6.15 google-api-core-2.24.2 google-api-python-client-2.168.0 google-auth-2.39.0 google-auth-httplib2-0.2.0 google-generativeai-0.8.5 googleapis-common-protos-1.70.0 grpcio-1.71.0 grpcio-status-1.71.0 httplib2-0.22.0 proto-plus-1.26.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.11.3 pydantic-core-2.33.1 rsa-4.9.1 tqdm-4.67.1 typing-inspection-0.4.0 uritemplate-4.1.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import google.generativeai as genai

# Configure your API key
genai.configure(api_key="AIzaSyD0tz9037cYpw4sYETT-WuoDlsd3NbopQs")

# List available models
models = genai.list_models()

# Print available models
for m in models:
    print(m.name)
# Out:
# models/chat-bison-001
# models/text-bison-001
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/aqa
# models/imagen-3.0-generate-002
# models/gemini-2.0-flash-live-001

# %%
import google.generativeai as genai

# Replace with your own API key
api_key = "AIzaSyD0tz9037cYpw4sYETT-WuoDlsd3NbopQs"

# Configure Gemini
genai.configure(api_key=api_key)

# Initialize the model
model = genai.GenerativeModel("models/gemini-1.5-pro-latest")

# Get user input
user_input = input("Describe the image you want to generate: ")

# Send request to Gemini for crafting a detailed prompt
response = model.generate_content(
    f"Craft a detailed image generation prompt for an AI image model based on this request: {user_input}"
)

# Print the AI-crafted prompt
print("\n📌 AI-Crafted Image Prompt:")
print(response.text)
# Out:
# 📌 AI-Crafted Image Prompt:
# ## Image Generation Prompt: Sukhoi Su-30 Flanker Fighter Jet
#
# **Subject:** A highly detailed and realistic image of a Sukhoi Su-30 Flanker fighter jet.
#
# **Composition:**
#
# * **Perspective:** Choose one of the following:
#     * **In-flight, dynamic pose:** Banking sharply, pulling high-G maneuvers, or flying low over terrain.
#     * **Static display:** On the tarmac, gear down, canopy open/closed.
#     * **Dramatic low angle:** Emphasizing the aircraft's size and power.
# * **Background:**  Choose one or combine elements:
#     * **Clear blue sky with realistic clouds:**  For a clean, focused image.
#     * **Dramatic sunset/sunrise:** For a more evocative and artistic feel.
#     * **Mountainous terrain:**  For a sense of power and agility.
#     * **Airshow environment:**  With crowds and other aircraft in the background (blurred for depth of field).
#     * **Active combat scenario:** Include missile trails, explosions, and other aircraft (use with caution, consider ethical implications).
# * **Lighting:** Realistic and corresponding to the chosen background and time of day.  Consider dramatic lighting to highlight the aircraft's features.
#
# **Aircraft Details:**
#
# * **Variant:** Specify the variant if desired (e.g., Su-30MKI, Su-30SM, Su-30MK2). Include specific features of that variant (e.g., canards, thrust vectoring nozzles).
# * **Markings and Livery:**
#     * **Specific air force:**  (e.g., Russian Aerospace Forces, Indian Air Force, Chinese People's Liberation Army Air Force) with accurate national insignia, tail numbers, and squadron emblems.
#     * **Generic fictional livery:**  Specify colors and patterns if desired.
# * **Weaponry:**  Specify if any weapons should be visible and which ones (e.g., R-77 air-to-air missiles, Kh-31 anti-ship missiles).
# * **Condition:**  Specify the aircraft's condition (e.g., pristine, weathered, battle-damaged).
# * **Canopy:** Open or closed.  If open, potentially include a visible pilot.
#
# **Style:** Photorealistic, high-resolution, highly detailed.
#
# **Keywords:**  Sukhoi Su-30, Flanker, fighter jet, military aircraft, aviation, supersonic, twin-engine, thrust vectoring, air superiority,  [add any other relevant keywords based on your chosen background, livery, etc.]
#
#
# **Example Prompts (combining elements from above):**
#
# * "Photorealistic image of a Russian Aerospace Forces Su-30SM performing a high-G turn against a backdrop of a dramatic sunset.  The aircraft should be armed with R-77 air-to-air missiles and have visible vapor trails. High resolution, highly detailed."
# * "A Su-30MKI of the Indian Air Force on static display at an airshow, with its canopy open and a pilot visible inside.  The background should be slightly blurred, showing other aircraft and crowds.  Clean, highly detailed, and photorealistic."
# * "Low-angle, dramatic shot of a weathered Su-30 Flanker flying low over mountainous terrain. The aircraft should have a generic grey camouflage livery.  Focus on the aircraft's size and power. High resolution, photorealistic."
#
#
# By combining these elements and using specific language, you can create a detailed and effective prompt for an AI image model to generate a stunning image of a Sukhoi Su-30 Flanker.  Remember to experiment with different prompts and keywords to achieve the desired results.
